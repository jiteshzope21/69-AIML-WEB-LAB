# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Jitesh Zope | Developer Portfolio</title>

    <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;600;700&display=swap" rel="stylesheet">

    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">

    <style>
        :root {
            /* Modern Dark Theme Palette */
            --bg-dark: #0f172a;       /* Deep Navy/Black */
            --bg-card: rgba(30, 41, 59, 0.7); /* Translucent Glass */
            --accent: #06b6d4;        /* Cyan/Teal Neon */
            --accent-gradient: linear-gradient(135deg, #06b6d4, #3b82f6);
            --text-main: #f8fafc;     /* Almost White */
            --text-muted: #94a3b8;    /* Soft Grey */
            --border: 1px solid rgba(255, 255, 255, 0.1);
        }

        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
            scroll-behavior: smooth;
        }

        body {
            font-family: 'Inter', sans-serif;
            background-color: var(--bg-dark);
            background-image: radial-gradient(circle at top right, #1e293b 0%, transparent 40%);
            color: var(--text-main);
            line-height: 1.6;
        }

        /* --- Layout Structure --- */
        .main-wrapper {
            max-width: 1100px;
            margin: 0 auto;
            padding: 40px 20px;
            display: grid;
            grid-template-columns: 300px 1fr; /* Sidebar | Content */
            gap: 40px;
        }

        /* --- Sidebar (Profile Card) --- */
        .profile-card {
            background: var(--bg-card);
            backdrop-filter: blur(10px);
            border: var(--border);
            border-radius: 20px;
            padding: 40px 20px;
            text-align: center;
            position: sticky; /* Sticks while scrolling */
            top: 40px;
            height: fit-content;
            box-shadow: 0 20px 40px rgba(0,0,0,0.3);
            animation: slideInLeft 0.8s ease-out;
            z-index: 10;
        }

        .profile-img-container {
            position: relative;
            width: 150px;
            height: 150px;
            margin: 0 auto 20px;
        }

        .profile-img {
            width: 100%;
            height: 100%;
            object-fit: cover;
            border-radius: 50%;
            border: 3px solid var(--accent);
            box-shadow: 0 0 20px rgba(6, 182, 212, 0.4);
        }

        .profile-name {
            font-size: 1.8rem;
            font-weight: 700;
            margin-bottom: 5px;
            letter-spacing: -0.5px;
        }

        .profile-role {
            color: var(--accent);
            font-weight: 600;
            margin-bottom: 20px;
            display: block;
        }

        .social-links {
            display: flex;
            justify-content: center;
            gap: 15px;
            margin-top: 25px;
            flex-wrap: wrap;
        }

        .social-icon {
            width: 40px;
            height: 40px;
            border-radius: 50%;
            background: rgba(255,255,255,0.05);
            display: flex;
            align-items: center;
            justify-content: center;
            color: var(--text-main);
            text-decoration: none;
            transition: 0.3s;
            border: var(--border);
        }

        .social-icon:hover {
            background: var(--accent);
            transform: translateY(-3px);
            box-shadow: 0 0 15px var(--accent);
            color: white;
        }

        /* --- Main Content Area --- */
        .content-area {
            animation: slideInUp 0.8s ease-out;
        }

        section {
            margin-bottom: 50px;
        }

        h2 {
            font-size: 1.5rem;
            border-bottom: 2px solid rgba(255,255,255,0.1);
            padding-bottom: 10px;
            margin-bottom: 25px;
            color: var(--text-main);
            display: flex;
            align-items: center;
            gap: 10px;
        }

        h2 i { color: var(--accent); }

        p { color: var(--text-muted); }

        /* --- Cards Generic Style --- */
        .info-card {
            background: var(--bg-card);
            border: var(--border);
            border-radius: 15px;
            padding: 25px;
            transition: 0.3s;
        }

        .info-card:hover {
            transform: translateY(-5px);
            border-color: var(--accent);
        }

        /* --- Skills Grid --- */
        .skills-grid {
            display: grid;
            grid-template-columns: repeat(auto-fill, minmax(140px, 1fr));
            gap: 15px;
        }

        .skill-item {
            background: rgba(255,255,255,0.03);
            padding: 15px;
            border-radius: 10px;
            text-align: center;
            border: var(--border);
            transition: 0.3s;
        }

        .skill-item:hover {
            background: rgba(6, 182, 212, 0.1);
            border-color: var(--accent);
        }

        .skill-item i {
            font-size: 2rem;
            margin-bottom: 10px;
            color: var(--accent);
        }

        /* --- Timeline (Education) --- */
        .timeline {
            position: relative;
            padding-left: 20px;
            border-left: 2px solid rgba(255,255,255,0.1);
        }

        .timeline-item {
            margin-bottom: 30px;
            position: relative;
        }

        .timeline-item::before {
            content: '';
            position: absolute;
            left: -26px;
            top: 5px;
            width: 14px;
            height: 14px;
            background: var(--accent);
            border-radius: 50%;
            box-shadow: 0 0 10px var(--accent);
        }

        .timeline-date {
            font-size: 0.85rem;
            color: var(--accent);
            font-weight: bold;
        }

        .timeline-title {
            font-size: 1.1rem;
            font-weight: 600;
            margin: 5px 0;
            color: var(--text-main);
        }

        .timeline-place {
            font-size: 0.9rem;
            color: var(--text-muted);
            font-style: italic;
        }

        /* --- Contact Form --- */
        .form-group {
            margin-bottom: 20px;
        }

        .form-control {
            width: 100%;
            padding: 12px 15px;
            background: rgba(0,0,0,0.2);
            border: 1px solid rgba(255,255,255,0.1);
            color: white;
            border-radius: 8px;
            font-family: inherit;
        }

        .form-control:focus {
            outline: none;
            border-color: var(--accent);
        }

        .btn-submit {
            background: var(--accent-gradient);
            color: white;
            border: none;
            padding: 12px 30px;
            border-radius: 30px;
            cursor: pointer;
            font-weight: 600;
            width: 100%;
            transition: 0.3s;
        }

        .btn-submit:hover {
            opacity: 0.9;
            box-shadow: 0 0 20px rgba(6, 182, 212, 0.4);
        }

        /* --- Footer --- */
        footer {
            text-align: center;
            padding-top: 40px;
            font-size: 0.9rem;
            color: var(--text-muted);
        }

        /* --- Mobile Responsive --- */
        @media (max-width: 768px) {
            .main-wrapper {
                grid-template-columns: 1fr; /* Stack layout on mobile */
            }
            .profile-card {
                position: relative;
                top: 0;
            }
        }

        /* --- Animations --- */
        @keyframes slideInLeft {
            from { opacity: 0; transform: translateX(-50px); }
            to { opacity: 1; transform: translateX(0); }
        }
        @keyframes slideInUp {
            from { opacity: 0; transform: translateY(50px); }
            to { opacity: 1; transform: translateY(0); }
        }
    </style>
</head>

<body>

    <div class="main-wrapper">

        <aside class="profile-card">
            <div class="profile-img-container">
                <img src="20250320_132008.jpeg" alt="Jitesh Zope" class="profile-img">
            </div>

            <h1 class="profile-name">Jitesh Zope</h1>
            <span class="profile-role">Computer Engineering Student</span>

            <p style="font-size: 0.9rem; margin-top: 15px;">
                Aspiring software developer passionate about Web Technologies, Python, and AI/ML.
            </p>

            <div class="social-links">
                <a href="https://www.linkedin.com/in/jiteshzope" target="_blank" class="social-icon" title="LinkedIn Profile">
                    <i class="fab fa-linkedin-in"></i>
                </a>

                <a href="https://github.com/jiteshzope21" target="_blank" class="social-icon" title="GitHub Profile">
                    <i class="fab fa-github"></i>
                </a>

                <a href="https://github.com/jiteshzope21/69-AIML-WEB-LAB" target="_blank" class="social-icon" title="View My Code">
                    <i class="fas fa-code-branch"></i>
                </a>

                <a href="mailto:your.email@example.com" class="social-icon" title="Send Email">
                    <i class="fas fa-envelope"></i>
                </a>
            </div>

            <div style="margin-top: 30px;">
                <a href="#contact" class="btn-submit" style="display:inline-block; text-decoration: none;">Hire Me</a>
            </div>
        </aside>

        <main class="content-area">

            <section class="info-card">
                <h2><i class="fas fa-user-astronaut"></i> About Me</h2>
                <p>
                    I am currently pursuing a Bachelor of Engineering at St. Francis Institute of Technology.
                    I have a strong foundation in problem-solving and am actively building projects to bridge
                    the gap between theory and real-world application. I enjoy learning new frameworks and
                    optimizing code for efficiency.
                </p>
            </section>

            <section>
                <h2><i class="fas fa-code"></i> Tech Stack</h2>
                <div class="skills-grid">
                    <div class="skill-item">
                        <i class="fab fa-python"></i>
                        <h4>Python</h4>
                    </div>
                    <div class="skill-item">
                        <i class="fab fa-html5"></i>
                        <h4>HTML/CSS</h4>
                    </div>
                    <div class="skill-item">
                        <i class="fab fa-java"></i>
                        <h4>Java</h4>
                    </div>
                    <div class="skill-item">
                        <i class="fas fa-database"></i>
                        <h4>SQL</h4>
                    </div>
                    <div class="skill-item">
                        <i class="fab fa-git-alt"></i>
                        <h4>Git</h4>
                    </div>
                    <div class="skill-item">
                        <i class="fas fa-brain"></i>
                        <h4>AI / ML</h4>
                    </div>
                </div>
            </section>

            <section class="info-card">
                <h2><i class="fas fa-graduation-cap"></i> Education</h2>
                <div class="timeline">

                    <div class="timeline-item">
                        <span class="timeline-date">2024 - 2028 (Present)</span>
                        <h3 class="timeline-title">Bachelor of Engineering</h3>
                        <p class="timeline-place">St. Francis Institute of Technology</p>
                    </div>

                    <div class="timeline-item">
                        <span class="timeline-date">2024</span>
                        <h3 class="timeline-title">Higher Secondary (HSC)</h3>
                        <p class="timeline-place">Bharat Vidyalaya Nhavi</p>
                    </div>

                    <div class="timeline-item">
                        <span class="timeline-date">2022</span>
                        <h3 class="timeline-title">Secondary School (SSC)</h3>
                        <p class="timeline-place">Bharat Vidyalaya Nhavi</p>
                    </div>

                </div>
            </section>

            <section class="info-card">
                <h2><i class="fas fa-gamepad"></i> Hobbies</h2>
                <p>
                    <i class="fas fa-check" style="color:var(--accent)"></i> Strategic Chess Player <br>
                    <i class="fas fa-check" style="color:var(--accent)"></i> Volleyball & Cricket Enthusiast <br>
                    <i class="fas fa-check" style="color:var(--accent)"></i> Tech Explorer
                </p>
            </section>

            <section class="info-card" id="contact">
                <h2><i class="fas fa-paper-plane"></i> Get In Touch</h2>
                <form>
                    <div class="form-group">
                        <input type="text" class="form-control" placeholder="Your Name">
                    </div>
                    <div class="form-group">
                        <input type="email" class="form-control" placeholder="Your Email">
                    </div>
                    <div class="form-group">
                        <textarea rows="4" class="form-control" placeholder="Message"></textarea>
                    </div>
                    <button type="submit" class="btn-submit">Send Message</button>
                </form>
            </section>

            <footer>
                <p>&copy; 2026 Jitesh Zope. Designed for the Future.</p>
            </footer>

        </main>
    </div>

</body>
</html>
