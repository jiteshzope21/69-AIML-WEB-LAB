# %%
<!DOCTYPE html>
<html>

<head>
    <title>Student Portfolio</title>
</head>

<body bgcolor="#f4f6f8">

    <center>
        <img src="20250320_132008.jpeg" width="150" height="150">
        <h1>JITESH ZOPE</h1>
        <p><i>Engineering Student | Beginner Software Developer</i></p>
    </center>

    <hr>

    <h2>Personal Information</h2>
    <p>
        Hello! I am <b>Jitesh Zope</b>, a passionate learner who is interested in
        programming and web technologies.
        Currently, I am pursuing my Bachelor of Engineering degree and exploring
        different areas of computer science.
    </p>

    <hr>

    <h2>Academic Details</h2>
    <center>
        <table border="1" cellpadding="10" cellspacing="0" width="80%">
            <tr>
                <th>Course</th>
                <th>College / School</th>
                <th>Completion Year</th>
            </tr>
            <tr>
                <td align="center">10th (SSC)</td>
                <td align="center">BHARAT VIDYALAYA NHAVI</td>
                <td align="center">2022</td>
            </tr>
            <tr>
                <td align="center">12th (HSC)</td>
                <td align="center">BHARAT VIDYALAYA NHAVI</td>
                <td align="center">2024</td>
            </tr>
            <tr>
                <td align="center">B.E. (Engineering)</td>
                <td align="center">St. Francis Institute of Technology</td>
                <td align="center">2024 – 2028</td>
            </tr>
        </table>
    </center>

    <hr>

    <h2>Technical Knowledge</h2>
    <ol>
        <li>HTML Web Page Creation</li>
        <li>Basic Web Concepts</li>
        <li>Python Programming</li>
        <li>Problem Solving</li>
        <li>Basic Java Concepts</li>
        <li>Introduction to AI & ML</li>
    </ol>

    <hr>

    <h2>Hobbies & Interests</h2>
    <ul>
        <li>I enjoy playing cricket and volleyball, which help me stay physically active and improve teamwork skills.</li>
        <li>I like playing chess as it enhances my logical thinking and decision-making abilities.</li>
        <li>I enjoy listening to music in my free time, as it helps me relax and stay focused.</li>
        <li>Learning new technologies</li>
        <li>Solving logical problems</li>
    </ul>

    <hr>

    <h2>Contact Form</h2>
    <form>
        <p>
            Full Name:<br>
            <input type="text" name="fullname">
        </p>

        <p>
            Email Address:<br>
            <input type="email" name="email">
        </p>

        <p>
            Feedback / Message:<br>
            <textarea rows="5" cols="40"></textarea>
        </p>

        <input type="submit" value="Send Message">
    </form>

    <hr>

    <center>
        <p>© Jitesh Portfolio</p>
    </center>

</body>

</html>
